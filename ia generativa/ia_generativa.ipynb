# %%
import pandas as pd

usuarios = pd.read_csv('SDW2023.csv').to_dict(orient='records')
usuarios_pd = pd.read_csv('SDW2023.csv')

usuarios_lista = pd.read_csv('SDW2023.csv').to_dict(orient='records')

#usuarios_pd.head()
#print(usuarios_pd)

for usuario in usuarios:
  usuario['news'] = []

print(usuarios)
# Out:
# [{'id': 1, 'nome': 'Naturo', 'news': []}, {'id': 2, 'nome': 'Hinata', 'news': []}]

# %%
def get_usuario(user_id):
  for usuario_item in usuarios:
    if usuario_item['id'] == int(user_id):
      return usuario_item

#print(get_usuario('1'))
usuarios = [found_user for user_dict in usuarios_lista if (found_user := get_usuario(user_dict['id'])) is not None]

print(usuarios)
# Out:
# [{'id': 1, 'nome': 'Naturo', 'news': []}, {'id': 2, 'nome': 'Hinata', 'news': []}]

# %%
open_ai_api_key = 'AIzaSyAgZcusAtyP7iJWOvHsWGUGfF_c7jAqXp0'

# %%
from google import genai

model = genai.Client(api_key=open_ai_api_key)

def generate_ai_news(usuario):
  # Use 'nome' as the key for the user's name based on the 'usuarios' data structure
  completion = model.models.generate_content(
    model="gemini-3-flash-preview",
    contents = f"Gerar notícias de tecnologia para o usuário: { usuario['nome'] } com no máximo 100 caracateres "
  )
  return completion.text

for usuario in usuarios:
  news = generate_ai_news(usuario)
  print(news)
  usuario['news'].append({"description": news})
# Out:
# IA e drones agora aceleram o reflorestamento global em 10x.
# Hinata: IA do Google cria vídeos reais e Apple lança novos iPads Pro!

# %%
import pandas as pd
import json

usuarios_for_save = []
for user_data in usuarios:
    user_copy = user_data.copy()
    if 'news' in user_copy and isinstance(user_copy['news'], list):
        user_copy['news'] = json.dumps(user_copy['news'], ensure_ascii=False)
    usuarios_for_save.append(user_copy)

updated_df = pd.DataFrame(usuarios_for_save)

updated_df.to_csv('SDW2023.csv', index=False)

print("SDW2023.csv atualizado com sucesso.")
# Out:
# SDW2023.csv updated successfully with news data.
